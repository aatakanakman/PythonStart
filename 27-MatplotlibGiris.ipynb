# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
yasListesi = [10,20,40,40,40,50,60,70,80,75]

# %%
kiloListesi = [20,60,80,85,86,87,70,90,95,80]

# %%
numpyYasListesi = np.array(yasListesi)
numpyKiloListesi = np.array(kiloListesi)

# %%
numpyKiloListesi
# Out:
# array([20, 60, 80, 85, 86, 87, 70, 90, 95, 80])

# %%
numpyYasListesi
# Out:
# array([10, 20, 40, 40, 40, 50, 60, 70, 80, 75])

# %%
plt.plot(numpyYasListesi,numpyKiloListesi,"b")  #Formatı (x,y,green) olarak yapmış oldu.
plt.xlabel("Yas")
plt.ylabel("Kilo")
plt.title("Kilo'nun yaşa göre değişim grafiği")
# Out:
# Text(0.5, 1.0, "Kilo'nun yaşa göre değişim grafiği")

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 **3

# %%
numpyDizisi2
# Out:
# array([0.00000000e+00, 1.45793847e-01, 1.16635078e+00, 3.93643388e+00,
#        9.33080624e+00, 1.82242309e+01, 3.14914711e+01, 5.00072897e+01,
#        7.46464499e+01, 1.06283715e+02, 1.45793847e+02, 1.94051611e+02,
#        2.51931768e+02, 3.20309083e+02, 4.00058318e+02, 4.92054235e+02,
#        5.97171599e+02, 7.16285173e+02, 8.50269719e+02, 1.00000000e+03])

# %%
plt.plot(numpyDizisi1,numpyDizisi2,"b*-")

# %%
plt.subplot(1,2,1)
plt.plot(numpyDizisi1,numpyDizisi2,"r*-")
plt.subplot(1,2,2) # 1 Sıra olacak, 2 kolon olacak , şu an 2. grafiği öiziyorum çiziyorum.
plt.plot(numpyDizisi2,numpyDizisi1,"g*-")

# %% [markdown]
# ## Kendimize Göre Şekillendirmek

# %%
benimFigure = plt.figure()
figureAxes = benimFiure.add_axes([0.1,0.1,0.3,0.3])
figureAxes.plot(numpyDizisi1,numpyDizisi2,"g*-")
figureAxes.set_xlabel("X Ekesni Veri İsmi")
figureAxes.set_ylabel("Y Ekseni Veri İsmi")
figureAxes.set_title("Grafik Başlığı")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-89-7b8a0f32e6a9> in <module>
#       1 benimFigure = plt.figure()
# ----> 2 figureAxes = benimFiure.add_axes([0.1,0.1,0.3,0.3])
#       3 figureAxes.plot(numpyDizisi1,numpyDizisi2,"g*-")
#       4 figureAxes.set_xlabel("X Ekesni Veri İsmi")
#       5 figureAxes.set_ylabel("Y Ekseni Veri İsmi")
#
# NameError: name 'benimFiure' is not defined

# %%
figure2 = plt.figure()

eksen1 = figure2.add_axes([0.1,0.1,0.9,0.9])
eksen2 = figure2.add_axes([0.2,0.4,0.3,0.3,])

eksen1.plot(numpyDizisi1,numpyDizisi2,"g--")
eksen1.set_xlabel("x ekseni")
eksen1.set_ylabel("y ekseni")
eksen1.set_title("Ana Grafik Başlık")

eksen2.plot(numpyDizisi2,numpyDizisi1,"b--")
eksen2.set_xlabel("x ekseni")
eksen2.set_ylabel("y ekseni")
eksen2.set_title("İkinci Grafik Başlık")
# Out:
# Text(0.5, 1.0, 'İkinci Grafik Başlık')

# %%
(benimFigure,benimEksenler)=plt.subplots(nrows =1,ncols=2)
#Subplot fiqure den farklı olarak tuple döndürür.Eksenler işin içine girer.
type(benimEksenler)
for eksen in benimEksenler:
    eksen.plot(numpyDizisi1,numpyDizisi2,"g")
    eksen.set_xlabel("x ekseni")

    plt.tight_layout() #aralarındaki mesafeyi otomatik olarak ayarlar.
#subplot bize bir tuple içerisinde eksenleri dizi olarak döndürüyor o yüzden onlara ulaşmak için for loop kullan-
#mamız gerekmektedir.

# %%
yeniFigure = plt.figure() #içerisine fgsize ve dpi(çözünürlük) verebiliriz.
yeniEksen = yeniFigure.add_axes([0.1,0.1,0.9,0.9])
yeniEksen.plot(numpyDizisi1,numpyDizisi1**2,label = "numpy dizisi **2")
yeniEksen.plot(numpyDizisi1,numpyDizisi1**3,label = "numpy dizisi **3")
yeniEksen.legend()   #legend in içerisine istediği loc u verebiliriz.

# %%
yeniFigure.savefig("benimfigur.png",dpi=100)
